# %% [markdown]
# # Basic Backtest
# Simple placeholder notebook showing where research prototypes will live.

# %%
import pandas as pd
import numpy as np

dates = pd.date_range("2024-01-01", periods=5, freq="D")
equity = pd.Series(100000 + np.cumsum(np.random.randn(5) * 1000), index=dates)
equity.plot(title="Toy Equity Curve")
